# %% [markdown]
# ### PROYECTO FINAL🌎

# %%
import pandas as pd

# %% [markdown]
# #### Temperaturas🌡️

# %%
temp=pd.read_csv("temperature.csv")

# %%
temp.head()
# Out:
#    Country         City           Jan           Feb           Mar  \
# 0  Algeria      Algiers  11.2\n(52.2)  11.9\n(53.4)  12.8\n(55.0)
# 1  Algeria  Tamanrasset  12.8\n(55.0)  15.0\n(59.0)  18.1\n(64.6)
# 2  Algeria      Reggane  16.0\n(60.8)  18.2\n(64.8)  23.1\n(73.6)
# 3   Angola       Luanda  26.7\n(80.1)  28.5\n(83.3)  28.6\n(83.5)
# 4    Benin      Cotonou  27.3\n(81.1)  28.5\n(83.3)  28.9\n(84.0)
#
#             Apr           May           Jun            Jul            Aug  \
# 0  14.7\n(58.5)  17.7\n(63.9)  21.3\n(70.3)   24.6\n(76.3)   25.2\n(77.4)
# 1  22.2\n(72.0)  26.1\n(79.0)  28.9\n(84.0)   28.7\n(83.7)   28.2\n(82.8)
# 2  27.9\n(82.2)  32.2\n(90.0)  36.4\n(97.5)  39.8\n(103.6)  38.4\n(101.1)
# 3  28.2\n(82.8)  27.0\n(80.6)  23.9\n(75.0)   22.1\n(71.8)   22.1\n(71.8)
# 4  28.6\n(83.5)  27.8\n(82.0)  26.5\n(79.7)   25.8\n(78.4)   25.6\n(78.1)
#
#             Sep           Oct           Nov           Dec          Year  \
# ...

# %% [markdown]
# #### Limpo las columnas:

# %%
def clean_columns(x):
    return x.split("\n")[0]

# %%
months=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","Year"]
for x in months:
    temp[x]=temp[x].apply(clean_columns)

# %%
temp.head()
# Out:
#    Country         City   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep  \
# 0  Algeria      Algiers  11.2  11.9  12.8  14.7  17.7  21.3  24.6  25.2  23.2
# 1  Algeria  Tamanrasset  12.8  15.0  18.1  22.2  26.1  28.9  28.7  28.2  26.5
# 2  Algeria      Reggane  16.0  18.2  23.1  27.9  32.2  36.4  39.8  38.4  35.5
# 3   Angola       Luanda  26.7  28.5  28.6  28.2  27.0  23.9  22.1  22.1  23.5
# 4    Benin      Cotonou  27.3  28.5  28.9  28.6  27.8  26.5  25.8  25.6  26.0
#
#     Oct   Nov   Dec  Year Continent
# 0  19.4  15.2  12.1  17.4    AFRICA
# 1  22.4  17.3  13.9  21.7    AFRICA
# 2  29.2  22.0  17.8  28.3    AFRICA
# 3  25.2  26.7  26.9  25.8    AFRICA
# 4  26.7  27.6  27.3  27.2    AFRICA

# %% [markdown]
# #### Compruebo que no hay nulos:

# %%
temp.isnull().sum()
# Out:
# Country      0
# City         0
# Jan          0
# Feb          0
# Mar          0
# Apr          0
# May          0
# Jun          0
# Jul          0
# Aug          0
# Sep          0
# Oct          0
# Nov          0
# Dec          0
# Year         0
# Continent    0
# dtype: int64

# %%
cities=list(temp.City.unique())

# %%
cities
# Out:
# ['Algiers',
#  'Tamanrasset',
#  'Reggane',
#  'Luanda',
#  'Cotonou',
#  'Parakou',
#  'Kandi',
#  'Maun',
#  'Gaborone',
#  'Ghanzi',
#  'Ouagadougou',
#  'Ouahigouya',
#  'Bujumbura',
#  'Garoua',
#  'Ngaoundéré',
#  'Douala',
#  'Yaoundé',
#  'Praia',
#  'Bangui',
#  'Birao',
#  "N'Djamena",
#  'Abéché',
#  'Kinshasa',
#  'Lubumbashi',
#  'Djibouti',
#  'Cairo',
#  'Alexandria',
#  'Bata',
#  'Malabo',
#  'Asmara',
#  'Assab',
#  "Mek'ele",
#  'Addis Ababa',
#  'Libreville',
#  'Port-Gentil',
#  'Banjul',
#  'Accra',
#  'Tamale',
#  'Kumasi',
#  'Conakry',
#  'Kankan',
#  'Bissau',
#  'Gagnoa',
#  'Bouaké',
#  'Abidjan',
#  'Odienné',
#  'Mombasa',
#  'Nairobi',
#  'Garissa',
#  'Lodwar',
#  'Tripoli',
#  'Benghazi',
#  'Fianarantsoa',
#  'Toamasina',
#  'Antananarivo',
#  'Antsiranana',
#  'Mahajanga',
#  'Toliara',
#  'Karonga',
#  'Blantyre',
#  'Mzuzu',
#  'Ségou',
#  'Timbuktu',
#  'Bamako',
#  'Nouadhibou',
#  'Nouakchott',
#  'Rabat',
#  'Marrakesh',
#  'Ouarzazate',
# ...

# %%
### Museos: Selenium--> https://en.wikipedia.org/wiki/Category:Lists_of_museums_by_city

# %%
### Idiomas: Selenium--> https://www.edestinos.com.mx/consejos-para-viajeros/pasajes-de-avion/documentos-y-visa/idiomas-oficiales-de-cada-pais

# %%
### Precio medio restaurantes: Selenium -->  Tripadvisor

# %%
### Hoteles --> https://businessblog.trivago.com/trivago-hotel-price-index/

# %% [markdown]
# ### Divisa:
