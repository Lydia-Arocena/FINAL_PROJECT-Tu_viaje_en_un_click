# %%
import requests
import pandas as pd
import os
from dotenv import load_dotenv
import os
import sys
sys.path.append('../')

import src.geo_functions as gf
import src.Restaurants_functions as rf

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Google API requests - Restaurants within a radious given a specific point:

# %%
response=rf.Google_Api_request("Madrid",10000)

# %% [markdown]
# ### Transforming Json to df with the relevant information:

# %%
restaurants=rf.cleaning_rest("Madrid",10000)

# %%
restaurants
# Out:
#                                     Name  Rating  \
# 0                  Restaurante Horoscopo     4.4
# 1   Restaurante "Las Trébedes de Bretón"     4.3
# 2                                   Èter     4.8
# 3                             Il Boccone     4.6
# 4                            Casa Pedro.     4.2
# 5                              Dominguez     4.2
# 6                   COCINA ASIATICA CHUN     4.4
# 7                   Nacho Bravo Taquería     4.5
# 8                           Kukaramakara     4.3
# 9             809 Madrid Bar Restaurante     4.3
# 10                BAR RESTAURANTE RAYMON     4.4
# 11                Restaurante Casa Lucía     4.4
# 12                            La Madreña     4.1
# 13                Restaurante Casa Egido     4.1
# 14                    Restobar Mama Rosa     4.4
# 15        Restaurante "Cervecería Conde"     4.5
# 16      Cantina Canalla Antracita Madrid     4.3
# 17                 The Names Restaurante     4.1
# 18                           Trasmontana     4.1
# 19                Arturo's Méndez Álvaro     4.3
#
#                                  Dirección    Latitud  Longitud
# 0             C. de Juana Doña, 16, Madrid  40.395833 -3.692955
# 1           C. de Tomás Bretón, 58, Madrid  40.396542 -3.691139
# 2               C. del Granito, 20, Madrid  40.393108 -3.691801
# 3         C. de Juan de Mariana, 4, Madrid  40.398948 -3.686939
# 4           C. de Tomás Bretón, 39, Madrid  40.397503 -3.692793
# 5       Paseo de las Delicias, 108, Madrid  40.395839 -3.694708
# 6        C. de Embajadores, 177, A, Madrid  40.392110 -3.693214
# 7       Paseo de las Delicias, 139, Madrid  40.391988 -3.694758
# 8           Cl. de San Evaristo, 3, Madrid  40.392974 -3.695372
# 9            P.º de la Chopera, 57, Madrid  40.392681 -3.696948
# 10           C. de Tomás Bretón, 2, Madrid  40.397472 -3.696108
# 11       C. de Rafael de Riego, 41, Madrid  40.401396 -3.692229
# 12                C. del Bronce, 4, Madrid  40.392398 -3.688548
# 13        Calle del Gral. Lacy, 50, Madrid  40.401127 -3.691121
# 14  C. de Alejandro Saint Aubin, 1, Madrid  40.393517 -3.696645
# 15       C. de Juan de Mariana, 19, Madrid  40.398770 -3.685750
# 16          C. de la Antracita, 10, Madrid  40.390329 -3.689718
# 17        Calle mezquite no2, loc7, Madrid  40.396971 -3.683268
# 18               C. de Bolívar, 18, Madrid  40.391938 -3.692136
# 19      C. de Méndez Álvaro, 64, b, Madrid  40.395961 -3.680989
