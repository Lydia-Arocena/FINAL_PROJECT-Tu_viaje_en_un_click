# %%
import requests
import os
from dotenv import load_dotenv
import pandas as pd
import sys
sys.path.append('../')
import src.weather_functions as wf

# %% [markdown]
# ### Wheather forecast API request:

# %%
load_dotenv()
# Out:
# True

# %%
wf.Api_request("Paris",3)
# Out:
# {'location': {'name': 'Paris',
#   'region': 'Ile-de-France',
#   'country': 'France',
#   'lat': 48.87,
#   'lon': 2.33,
#   'tz_id': 'Europe/Paris',
#   'localtime_epoch': 1639594238,
#   'localtime': '2021-12-15 19:50'},
#  'current': {'last_updated_epoch': 1639593000,
#   'last_updated': '2021-12-15 19:30',
#   'temp_c': 7.0,
#   'temp_f': 44.6,
#   'is_day': 0,
#   'condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#    'code': 1003},
#   'wind_mph': 0.0,
#   'wind_kph': 0.0,
#   'wind_degree': 0,
#   'wind_dir': 'N',
#   'pressure_mb': 1034.0,
#   'pressure_in': 30.53,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 87,
#   'cloud': 25,
#   'feelslike_c': 7.1,
#   'feelslike_f': 44.8,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 1.0,
#   'gust_mph': 3.4,
#   'gust_kph': 5.4},
#  'forecast': {'forecastday': [{'date': '2021-12-15',
#     'date_epoch': 1639526400,
#     'day': {'maxtemp_c': 9.1,
# ...

# %% [markdown]
# ### Transforming Json to df with the relevant information:

# %%
data=wf.cleaning("Paris",3)

# %%
data.head()
# Out:
#         Dates  Min_temp  Max_temp  Rain  Snow            Sky  \
# 0  2021-12-15       4.2       9.1     0     0  Partly cloudy
# 1  2021-12-16       6.2      13.3     0     0  Partly cloudy
# 2  2021-12-17       4.9      10.9     0     0          Clear
#
#                                                Icon
# 0  //cdn.weatherapi.com/weather/64x64/night/113.png
# 1  //cdn.weatherapi.com/weather/64x64/night/116.png
# 2  //cdn.weatherapi.com/weather/64x64/night/113.png

# %%
wf.dibu3(data)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=64x64 at 0x7F5EFCC80700>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=64x64 at 0x7F5EFCBA4B80>
